# %%
import pandas as pd

data = pd.read_csv("SIS.csv")

class Student_sorting:
    def __init__(self, file, data):
        self.file = file
        self.data = data

    def age_sorting(self):
        pirates = []
        yankees = []
        bulls = []
        for index, row in self.data.iterrows():
            age =  row["Age"]
            if age > 14 and age < 18:
                pirates.append(row)
            elif age > 18 and age < 22:
                yankees.append(row)
            elif age > 22 and age < 25:
                bulls.append(row)
            else:
                error = Encapsulation_error_handling(age, row)
                print(error.error_getter())
        Pirates_df = pd.DataFrame(pirates)
        Pirates_df.to_csv("The Pirates.csv", index = False)
        Yankees_df = pd.DataFrame(yankees)
        Yankees_df.to_csv("The Yankees.csv", index = False)
        Bulls_df = pd.DataFrame(bulls)
        Bulls_df.to_csv("The Bulls.csv", index = False)

        print("PIRATES")
        print(Pirates_df)
        print("YANKEES")
        print(Yankees_df)
        print("BULLS")
        print(Bulls_df)

class Encapsulation_error_handling:
    def __init__(self, age, record):
        self.__age = age
        self.name = record["Name"]

    def error_getter(self):
        return f"Student {self.name} is out of range for classification.(Age: {self.__age})"

system = Student_sorting("SIS.csv", data)
system.age_sorting()
Student Martin Alegbe is out of range for classification.(Age: 25)
Student Gabriel Pati is out of range for classification.(Age: 18)
Student Kolawole Alabi is out of range for classification.(Age: 27)
Student Tope Ogunleye is out of range for classification.(Age: 22)
Student Edith Ade is out of range for classification.(Age: 22)
Student Adelabu Glory is out of range for classification.(Age: 26)
Student Abraham Esther is out of range for classification.(Age: 28)
Student Agbara Jamiat is out of range for classification.(Age: 26)
PIRATES
    MatNo               Name  Age  Grade
0    1810       Aina Adeleke   16     80
2    1812    Callistus Okeke   17     40
5    1815    Stella Olohimen   17     44
10   1820  Wilfred Nwachukwu   16     45
11   1821      Mildred James   15     70
YANKEES
    MatNo               Name  Age  Grade
4    1814        Mary Akande   20     87
12   1822     Glory Babalola   21     69
14   1824      Godwin Osahon   20     51
15   1825       Philip Odion   19     68
17   1827         Igor Lawal   20     55
20   1830  Gbemisola Adewale   21     80
BULLS
   MatNo             Name  Age  Grade
1   1811      Sola Egbune   23     55
7   1817  Durojaiye Adamu   24     60
# Out:
#   Cell In[5], line 49
#     Student Martin Alegbe is out of range for classification.(Age: 25)
#             ^
# SyntaxError: invalid syntax
