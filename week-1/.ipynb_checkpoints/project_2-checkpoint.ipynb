# %%
# Compound Interest Program

# input values
P = float(input("Enter Principal: "))
R = float(input("Enter Rate: "))
n = float(input("Enter number of times interest compounded per year: "))
t = float(input("Enter Time in years: "))

# calculation
A = P * (1 + R/n) ** (n * t)

# output
print("Compound Interest =", CI)
print("Data Type of CI is", type(A))
# Out:
# Enter Principal:  200000
# Enter Rate:  2
# Enter number of times interest compounded per year:  2
# Enter Time in years:  3
# Compound Amount = 12800000.0
# Data Type of Amount is <class 'float'>
