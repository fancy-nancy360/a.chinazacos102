# %% [markdown]
# Start
# Input total amount
# Display total amount
# Input payment
#
# IF
#    payment >= total amount THEN
#    DISPLAY "Print Receipt"
# ELSE
#    DISPLAY "Insufficient Payment"
# DISPLAY "Show receipt to doorman"
# DISPLAY "Exit Store"
#  Stop

# %% [markdown]
# ![image.png](attachment:e8e5c081-8fce-4fa1-98c6-70d1437089b9.png)![image.png](attachment:6ffaae92-bf28-4193-927e-a754d022c8a0.png)

# %% [markdown]
# ![Screenshot 2026-03-11 234225.png](attachment:a5918625-3671-4453-a9fc-37afd180cc82.png)

# %%
Start
Input Name1 and Age1
Input Name2 and Age2
Store Age1 in a temporary variable(Temp)
Set Age1=Age2
Set Age2=Temp
Display Name1 and new Age1
Display Name2 and new Age2
Stop
