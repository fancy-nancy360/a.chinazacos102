# %%
Start
Create lists for names, ages, heights, and scores.
Insert the values for all students.
Combine the lists so each student's data matches correctly.
Print a table with the headings: Name, Age, Height, Score.
Display each student’s record in tabular form.
Stop.

# %%
# Student data

names = ["Evelyn","Jessica","Somto","Edith","Liza","Madonna","Waje","Tola","Aisha","Latifa",
         "Chinedu","Liam","Wale","Gbenga","Abiola","Kola","Kunle","George","Thomas","Wesley"]

ages = [17,16,17,18,16,18,17,20,19,17,19,16,18,17,20,19,16,18,17,19]

heights = [5.5,6.0,5.4,5.9,5.6,5.5,6.1,6.0,5.7,5.5,5.7,5.9,5.8,6.1,5.9,5.5,6.1,5.4,5.8,5.7]

scores = [80,85,70,60,76,66,87,95,50,49, 74,87,75,68,66,78,87,98,54,60]

# Print table header
print("Name\tAge\tHeight\tScore")

# Loop through the lists
for i in range(len(names)):
    print(names[i], "\t", ages[i], "\t", heights[i], "\t", scores[i])
